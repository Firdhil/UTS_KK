# %% [markdown]
# <a href="https://colab.research.google.com/github/Firdhil/UTS_KK/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
def linear(x):
    ''' y = f(x) It returns the input as it is'''
    return x

# %%
x = np.linspace(-10, 10, 5)
plt.plot(x, linear(x))
plt.axis('tight')
plt.title('Activation Function :Linear')
plt.show()
